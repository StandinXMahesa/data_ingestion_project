# %%
import pandas as pd 
from sqlalchemy import create_engine

# %%
df = pd.read_csv("src\yellow_tripdata_2021-01.csv",parse_dates=['tpep_pickup_datetime','tpep_dropoff_datetime'])
df_iter = pd.read_csv('src/yellow_tripdata_2021-01.csv', iterator=True, chunksize=100000,parse_dates=['tpep_pickup_datetime','tpep_dropoff_datetime'])
display(df.head(5))
# Out:
# C:\Users\ganes\AppData\Local\Temp\ipykernel_18204\1248146818.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("src\yellow_tripdata_2021-01.csv",parse_dates=['tpep_pickup_datetime','tpep_dropoff_datetime'])
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1       1.0  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2       1.0  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3       1.0  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4       2.0  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# ...

# %%
enginer = create_engine('postgresql://root:root@localhost:5432/ny_taxi')
enginer.connect()

# %%
df_temp = next(df_iter)
# %time df_temp.to_sql(name="yellow_taxi_data",con=enginer,if_exists="append")
# Out:
# CPU times: total: 4.7 s
# Wall time: 11.4 s
# 1000

# %%
pd.read_sql("""SELECT * FROM yellow_taxi_data;""",con=enginer)
# Out:
#         index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0      100000         2  2021-01-04 14:42:51   2021-01-04 14:51:18
# 1      100001         2  2021-01-04 14:04:39   2021-01-04 14:18:41
# 2      100002         1  2021-01-04 14:12:49   2021-01-04 14:31:21
# 3      100003         1  2021-01-04 14:43:55   2021-01-04 14:48:45
# 4      100004         1  2021-01-04 14:59:16   2021-01-04 15:07:08
# ...       ...       ...                  ...                   ...
# 99995  199995         1  2021-01-06 17:02:39   2021-01-06 17:09:21
# 99996  199996         1  2021-01-06 17:12:00   2021-01-06 17:17:55
# 99997  199997         2  2021-01-06 17:03:41   2021-01-06 17:07:37
# 99998  199998         2  2021-01-06 17:14:11   2021-01-06 17:29:58
# 99999  199999         2  2021-01-06 17:45:43   2021-01-06 17:52:37
#
#        passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                    1           1.43           1                  N
# ...
